# %% [markdown]
# **Cell #01**
#
# # Yoga-Sūtra: five questions, answered from Michel Angot's edition
#
# Ask questions about the **Yoga-Sūtra of Patañjali and the Yoga-Bhāṣya** and get answers grounded in the book
# (Michel Angot, French edition, 2021), with the pages they come from. Questions can be in any language or script,
# including Devanagari; the answers are always written in the language you choose in the next cell.
#
# Behind the scenes (all in `reusable_code/ys/`): each question is understood and turned into a clean search query,
# matched against this one book only, and answered strictly from the passages found.
#
# *Needs the book loaded in the database. If it is not fully loaded, the next cell says exactly what to do.*

# %%
# Cell #02
from reusable_code.ys import YogaSutraQA

ys = YogaSutraQA(speaking_language="EN")   # answers are written in this language: EN, RU, FR, HI, ...

# %% [markdown]
# **Cell #03**
#
# ## The questions
#
# Edit, add or remove questions freely. Two quote a sūtra in Devanagari, one is written entirely in Hindi, and one
# asks for a comparison across several sūtras.

# %%
# Cell #04
QUESTIONS = [
    "योगश्चित्तवृत्तिनिरोधः — what does Yoga-Sūtra I.2 define yoga as, and how does the Bhāṣya explain the word nirodha?",
    "Why does Angot read the opening word 'atha' of Yoga-Sūtra I.1 as an adhikāra, and who are the intended addressees of the text?",
    "अहिंसाप्रतिष्ठायां तत्सन्निधौ वैरत्यागः — according to II.35, what happens in the presence of someone firmly established in ahiṃsā?",
    "How do the five vṛtti-s (pramāṇa, viparyaya, vikalpa, nidrā, smṛti) differ from one another, and which of them can be kliṣṭa or akliṣṭa?",
    "क्या योगसूत्र में ईश्वर जगत् का सृष्टिकर्ता है?",
]

# %% [markdown]
# **Cell #05**
#
# ## The answers

# %%
# Cell #06
answers = ys.ask_all(QUESTIONS)

# %% [markdown]
# **Cell #07**
#
# ## Save workspace to GitHub

# %%
# Cell #08
from reusable_code import save_to_github

save_to_github("stage2_ask_examples7_ys.ipynb - Yoga-Sutra questions and answers")
