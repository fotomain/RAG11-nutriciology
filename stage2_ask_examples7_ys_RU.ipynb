# %% [markdown]
# **Cell #01**
#
# # Йога-сутра: пять вопросов и ответы по изданию Мишеля Анго
#
# Задавайте вопросы о **Йога-сутре Патанджали и Йога-бхашье** и получайте ответы, опирающиеся на книгу
# (Мишель Анго, французское издание, 2021), с указанием страниц. Вопросы можно задавать на любом языке и в любой
# письменности, включая деванагари; ответы всегда пишутся на языке, выбранном в следующей ячейке (здесь: русский).
#
# За кулисами (весь код в `reusable_code/ys/`): каждый вопрос понимается и превращается в чистый поисковый запрос,
# ищется только в этой книге, а ответ строится строго по найденным фрагментам.
#
# *Нужна книга, загруженная в базу данных. Если она загружена не полностью, ячейка настройки подскажет, что делать.*
#
# **Системный промпт можно редактировать** (ячейка ниже): это инструкция, по которой модель отвечает. Измените её,
# запустите ячейки снова и сравните ответы.

# %% [markdown]
# **Cell #02**
#
# ## Системный промпт (можно править)
#
# Так модель получает свою роль и правила: отвечать только по найденным фрагментам, указывать номер сутры, различать
# Сутру, Бхашью и комментарий Анго, ставить строку `Short answer: Yes|No` только у настоящих вопросов «да/нет».
#
# - **Язык ответа** (русский) добавляется автоматически из `speaking_language`, в промпт его писать не нужно.
# - Строку `Short answer: Yes|No` лучше сохранить: по ней рисуется значок «Да/Нет» у вопросов «да/нет».
# - Чтобы вернуться к исходному тексту, поставьте `SYSTEM_PROMPT = None` (или удалите параметр `system_prompt=`).

# %%
# Cell #03
# Системный промпт: правьте текст между тройными кавычками
SYSTEM_PROMPT = """You are a research assistant for a French scholarly edition of the Yoga-Sutra of Patanjali and the Yoga-Bhasya of Vyasa (Michel Angot, 3rd edition 2021). Answer strictly using the numbered excerpts in the user message -- do not rely on outside knowledge, and say plainly if the excerpts don't contain enough information to answer.

The excerpts are mostly French; Sanskrit appears in IAST transliteration. The question may be written in any language or script; lines such as "[English: ...]" or "[IAST: ...]" after it are its translation and transliteration, added to help you.

Whenever the excerpts allow it: give the sutra reference (e.g. II.35), quote the key Sanskrit term in IAST, and say whether a claim comes from the Sutra itself, from the Bhasya, or from Angot's own commentary.

First decide whether the question is a Yes/No question, i.e. it is worded as a yes/no question in its own language ("is/does/can/are ...?", "क्या ...?", "... ли ...?", "est-ce que ...?") and a plain yes or no truly answers it. Questions that ask "what", "how", "why", "who", "which", or "what happens" are NEVER Yes/No questions, however the excerpts turn out.
  - If it is a Yes/No question, begin your reply with exactly this one line:
        Short answer: Yes
    or
        Short answer: No
    then a blank line, then the full explanation.
  - Otherwise skip the "Short answer" line and give the full explanation.
  - If the excerpts do not contain enough to answer, never write a "Short answer" line: say what is missing.

Keep the explanation grounded in the excerpts."""

# %% [markdown]
# **Cell #04**
#
# ## Настройка

# %%
# Cell #05
from reusable_code.ys import YogaSutraQA

ys = YogaSutraQA(
    speaking_language="RU",         # ответы пишутся на этом языке: RU, EN, FR, HI, ...
    system_prompt=SYSTEM_PROMPT,    # ваш системный промпт (None = исходный)
)
# Out:
# Yoga-Sutra book ready: 314 text chunks, 0 of 195 sutra sections loaded.
# WARNING: the sutra text is not fully loaded, so questions about individual sutras will be answered with 'the excerpts do not contain ...'. To load it:
#   1. in .env set MAX_NUMBER_OF_PAGES_TO_USE=NONE (and restart the notebook kernel)
#   2. re-run stage1_1_extract_and_chunk.ipynb, then stage1_2_eda_load_chunks.ipynb (only new/changed chunks are embedded)
#   3. stage1_9_eda_verify_all_data.ipynb should print PASS
# System prompt: built-in default (pass system_prompt=... to change it).

# %% [markdown]
# **Cell #06**
#
# ## Вопросы
#
# Вопросы можно свободно менять, добавлять и удалять. В двух цитируется сутра на деванагари, один — сравнение
# нескольких сутр, один — вопрос «да/нет».

# %%
# Cell #07
QUESTIONS = [
    "योगश्चित्तवृत्तिनिरोधः — что определяет Йога-сутра I.2 как йогу и как Бхашья объясняет слово ниродха?",
    "Почему Анго читает первое слово «атха» в Йога-сутре I.1 как адхикару и кто предполагаемые адресаты текста?",
    "अहिंसाप्रतिष्ठायां तत्सन्निधौ वैरत्यागः — что, согласно II.35, происходит в присутствии того, кто твёрдо утвердился в ахимсе?",
    "Чем отличаются друг от друга пять вритти (прамана, випарьяя, викальпа, нидра, смрити) и какие из них могут быть клишта или аклишта?",
    "Является ли Ишвара в Йога-сутре творцом мира?",
]

# %% [markdown]
# **Cell #08**
#
# ## Ответы

# %%
# Cell #09
answers = ys.ask_all(QUESTIONS)
# Out:
# <style>
# .ys-card{border:1px solid rgba(128,128,128,.35);border-radius:12px;padding:16px 20px;margin:18px 0;height:auto;
#   max-height:none;overflow:visible;line-height:1.6;font-size:14.5px;max-width:980px}
# .ys-label{font-size:11px;letter-spacing:.09em;text-transform:uppercase;font-weight:700;opacity:.6;margin:0 0 5px}
# .ys-q{font-size:15.5px;font-weight:600;margin:0 0 4px;padding:9px 13px;border-left:4px solid #2a78d6;
#   background:rgba(42,120,214,.10);border-radius:4px;white-space:pre-wrap;overflow-wrap:anywhere}
# .ys-iast{font-size:12.5px;opacity:.7;margin:4px 0 0 17px;overflow-wrap:anywhere}
# .ys-a{margin-top:14px;overflow-wrap:anywhere}
# .ys-a p{margin:0 0 .85em}
# .ys-a h4{margin:1em 0 .4em;font-size:1em}
# .ys-a ul{margin:0 0 .85em 1.3em;padding:0}
# .ys-a li{margin:.2em 0}
# .ys-a code{background:rgba(128,128,128,.18);border-radius:4px;padding:0 4px}
# .ys-badge{display:inline-block;padding:3px 12px;border-radius:999px;font-weight:700;font-size:12.5px;color:#fff;margin-bottom:10px}
# .ys-yes{background:#0b7a4b}.ys-no{background:#b23b2e}
# .ys-lang{display:inline-block;padding:1px 8px;border-radius:999px;font-size:11px;font-weight:700;margin-left:8px;
#   border:1px solid rgba(128,128,128,.5);opacity:.8;letter-spacing:.04em}
# .ys-meta{margin-top:12px;padding-top:9px;border-top:1px dashed rgba(128,128,128,.45);font-size:12px;opacity:.75;overflow-wrap:anywhere}
# table.ys-tbl{border-collapse:collapse;font-size:13px;margin:10px 0}
# table.ys-tbl th,table.ys-tbl td{border-bottom:1px solid rgba(128,128,128,.35);padding:5px 12px;text-align:left;vertical-align:top}
# table.ys-tbl th{font-size:11px;text-transform:uppercase;letter-spacing:.06em;opacity:.7}
# </style><div class="ys-card"><div class="ys-label">Вопрос 1:<span class="ys-lang">RU</span></div><div class="ys-q">योगश्चित्तवृत्तिनिरोधः — что определяет Йога-сутра I.2 как йогу и как Бхашья объясняет слово ниродха?</div><div class="ys-iast">IAST: yogaścittavṛttinirodhaḥ — что определяет Йога-сутра I.2 как йогу и как Бхашья объясняет слово ниродха?</div><div class="ys-iast">Поисковый запрос: Yoga-sūtra I.2 yogaḥ cittavṛttinirodhaḥ définition du yoga et explication du terme nirodha dans le Bhāṣya</div><div class="ys-a"><div class="ys-label">Ответ:</div><h4>Йога-сутра I.2 и толкование ниродха в Бхашье</h4><h4>Формулировка сутры</h4><p>Сутра I.2 (cittavṛttinirodhaḥ) в переводе Анго звучит так: «Йога есть остановка колебаний менталя» («Le yoga est l&#x27;arrêt des fluctuations du mental»). Однако Анго (в комментарии) отмечает важную грамматическую особенность: порядок слов в этой сутре нетипичен для определений в стиле сутр (например, у Панини), где определяемое (то, что называется) обычно предшествует термину. Ожидалось бы <i>cittavṛttinirodho yogaḥ</i>, но текст даёт обратный порядок.</p><p>Из этого Анго делает вывод (Excerpt 4, его собственный комментарий): возможно, I.1 — это не определение (не lakṣaṇa в строгом смысле), а установление <b>asādharaṇadharma</b> («исключительного свойства») йоги. Предлагаемый перевод с учётом этого: «остановка колебаний менталя [характеризует] йогу» — то есть не строгое определение, а указание на существенный признак.</p><h4>Как Бхашья объясняет ниродха</h4><p>Здесь Анго указывает на противоречие между Сутрой и Бхашьей (Excerpt 1, комментарий Анго со ссылкой на YBh I.1):</p><ul><li>Бхашья к I.1 превращает состояние <b>niruddha</b> («остановленное») менталя в <b>уровень активности</b> менталя (наряду с другими уровнями), а не в полное отсутствие всякой активности.</li><li>Бхашья утверждает, что это состояние niruddha одновременно является <b>sārvabhauma</b> («присутствующим на всех уровнях»).</li><li>Из этого следует парадоксальный вывод, отмеченный Анго: <b>nirodha скорее выступает как «колебание остановки» (une vṛtti d&#x27;arrêt), а не как «остановка колебаний»</b> в буквальном смысле.</li></ul><h4>Уточнение из YBh I.2 (Excerpt 3, со ссылкой на бхашьякару)</h4><p>Анго отмечает ещё одно важное расширение смысла в самой Бхашье к I.2: поскольку Сутра не сказала «йога есть остановка <b>всех</b> колебаний менталя», <b>YBh I.2</b> утверждает, что слово <i>yoga</i> обозначает:<br>1.</p></div><div class="ys-meta">6 фрагментов (лучшие из 24 кандидатов)<br>страницы 71-110<br>подвопросы: Quelle est la définition du yoga selon le Yoga-sūtra I.2, yogaḥ cittavṛttinirodhaḥ ? &#124; Comment le Bhāṣya explique-t-il le terme nirodha dans le Yoga-sūtra I.2 ?<br>опирается на: cittav, ttinirodha, yoga, est, l&#x27;arr, des, fluctuations, mental, ttinirodho, lak, dhara, adharma</div></div>
# <style>
# .ys-card{border:1px solid rgba(128,128,128,.35);border-radius:12px;padding:16px 20px;margin:18px 0;height:auto;
#   max-height:none;overflow:visible;line-height:1.6;font-size:14.5px;max-width:980px}
# .ys-label{font-size:11px;letter-spacing:.09em;text-transform:uppercase;font-weight:700;opacity:.6;margin:0 0 5px}
# .ys-q{font-size:15.5px;font-weight:600;margin:0 0 4px;padding:9px 13px;border-left:4px solid #2a78d6;
#   background:rgba(42,120,214,.10);border-radius:4px;white-space:pre-wrap;overflow-wrap:anywhere}
# .ys-iast{font-size:12.5px;opacity:.7;margin:4px 0 0 17px;overflow-wrap:anywhere}
# .ys-a{margin-top:14px;overflow-wrap:anywhere}
# .ys-a p{margin:0 0 .85em}
# .ys-a h4{margin:1em 0 .4em;font-size:1em}
# .ys-a ul{margin:0 0 .85em 1.3em;padding:0}
# .ys-a li{margin:.2em 0}
# .ys-a code{background:rgba(128,128,128,.18);border-radius:4px;padding:0 4px}
# .ys-badge{display:inline-block;padding:3px 12px;border-radius:999px;font-weight:700;font-size:12.5px;color:#fff;margin-bottom:10px}
# .ys-yes{background:#0b7a4b}.ys-no{background:#b23b2e}
# .ys-lang{display:inline-block;padding:1px 8px;border-radius:999px;font-size:11px;font-weight:700;margin-left:8px;
#   border:1px solid rgba(128,128,128,.5);opacity:.8;letter-spacing:.04em}
# .ys-meta{margin-top:12px;padding-top:9px;border-top:1px dashed rgba(128,128,128,.45);font-size:12px;opacity:.75;overflow-wrap:anywhere}
# table.ys-tbl{border-collapse:collapse;font-size:13px;margin:10px 0}
# table.ys-tbl th,table.ys-tbl td{border-bottom:1px solid rgba(128,128,128,.35);padding:5px 12px;text-align:left;vertical-align:top}
# table.ys-tbl th{font-size:11px;text-transform:uppercase;letter-spacing:.06em;opacity:.7}
# </style><div class="ys-card"><div class="ys-label">Вопрос 2:<span class="ys-lang">RU</span></div><div class="ys-q">Почему Анго читает первое слово «атха» в Йога-сутре I.1 как адхикару и кто предполагаемые адресаты текста?</div><div class="ys-iast">Поисковый запрос: Pourquoi Angot interprète-t-il le mot « atha » au début du Yoga-Sutra I.1 comme un adhikāra, et qui sont les destinataires supposés du texte ?</div><div class="ys-a"><div class="ys-label">Ответ:</div><p>К сожалению, предоставленные фрагменты не содержат информации о том, как Анго толкует слово «atha» в первой сутре (YS I.1) — ни цитаты, ни комментария по этому конкретному термину в них нет, поэтому ответить на первую часть вопроса невозможно на основании данных excerpts.</p><p>Что же касается предполагаемых адресатов текста, здесь материал есть, и он относится к Bhāṣya (комментарию Вьясы), а не к самой Сутре, в изложении Анго (Excerpt 1, раздел «Introduction — A. Le Yoga-Sūtra et la tradition du yoga»):</p><ul><li>Анго пишет, что <i>bhāṣyakāra</i> (автор Бхашьи) «adresse ouvertement aux brahmanes et à eux seuls» (открыто обращается к брахманам, и только к ним), и что «à plusieurs reprises dans son commentaire, le bhāṣyakāra mentionne les brahmanes comme les usagers et donc les destinataires du texte» (неоднократно в своём комментарии бхашьякара упоминает брахманов как пользователей и, следовательно, адресатов текста).</li><li>Анго уточняет, что происходит не столько «védisation» (оведение), сколько «brahmanisation» текста — то есть а) утверждение, что брахманы являются адресатами текста, и б) анализ Йога-сутры в рамках системы отсылок, характерных для брахманов эпохи бхашьякары, происходящих главным образом из Пурана, а не из Вед.</li><li>В качестве примера приводится YS III.26, где сутра фактически не объясняется, а служит предлогом для изложения пуранической космографии (учения об адах), чуждого доктрине самой Йога-сутры.</li><li>Другой пример — определение термина <i>svādhyāya</i> под YS II.1: в миманскую ортодоксию оно означало «личную декламацию [Вед]», тогда как Бхашья даёт иное толкование (текст обрывается на этом месте во фрагменте).</li></ul><p>Также в Excerpt 4 (та же секция, из комментария Анго) поясняется, что редакция YS на санскрите — это процесс «брахманизации»: практики и представления, изначально не брахманические и не брахманистские, записываются на санскрите и, по крайней мере в Бхашье, предназначены для санскритоговор</p></div><div class="ys-meta">6 фрагментов (лучшие из 24 кандидатов)<br>страницы 3-5, 13-51<br>подвопросы: Pourquoi Angot interprète-t-il le mot « atha » au début du Yoga-Sutra I.1 comme un adhikāra ? &#124; Selon Angot, qui sont les destinataires supposés du Yoga-Sutra ?<br>опирается на: introduction, yoga, tra, tradition, yak, ouvertement, aux, brahmanes, eux, seuls, plusieurs, reprises</div></div>
# <style>
# .ys-card{border:1px solid rgba(128,128,128,.35);border-radius:12px;padding:16px 20px;margin:18px 0;height:auto;
#   max-height:none;overflow:visible;line-height:1.6;font-size:14.5px;max-width:980px}
# .ys-label{font-size:11px;letter-spacing:.09em;text-transform:uppercase;font-weight:700;opacity:.6;margin:0 0 5px}
# .ys-q{font-size:15.5px;font-weight:600;margin:0 0 4px;padding:9px 13px;border-left:4px solid #2a78d6;
#   background:rgba(42,120,214,.10);border-radius:4px;white-space:pre-wrap;overflow-wrap:anywhere}
# .ys-iast{font-size:12.5px;opacity:.7;margin:4px 0 0 17px;overflow-wrap:anywhere}
# .ys-a{margin-top:14px;overflow-wrap:anywhere}
# .ys-a p{margin:0 0 .85em}
# .ys-a h4{margin:1em 0 .4em;font-size:1em}
# .ys-a ul{margin:0 0 .85em 1.3em;padding:0}
# .ys-a li{margin:.2em 0}
# .ys-a code{background:rgba(128,128,128,.18);border-radius:4px;padding:0 4px}
# .ys-badge{display:inline-block;padding:3px 12px;border-radius:999px;font-weight:700;font-size:12.5px;color:#fff;margin-bottom:10px}
# .ys-yes{background:#0b7a4b}.ys-no{background:#b23b2e}
# .ys-lang{display:inline-block;padding:1px 8px;border-radius:999px;font-size:11px;font-weight:700;margin-left:8px;
#   border:1px solid rgba(128,128,128,.5);opacity:.8;letter-spacing:.04em}
# .ys-meta{margin-top:12px;padding-top:9px;border-top:1px dashed rgba(128,128,128,.45);font-size:12px;opacity:.75;overflow-wrap:anywhere}
# table.ys-tbl{border-collapse:collapse;font-size:13px;margin:10px 0}
# table.ys-tbl th,table.ys-tbl td{border-bottom:1px solid rgba(128,128,128,.35);padding:5px 12px;text-align:left;vertical-align:top}
# table.ys-tbl th{font-size:11px;text-transform:uppercase;letter-spacing:.06em;opacity:.7}
# </style><div class="ys-card"><div class="ys-label">Вопрос 3:<span class="ys-lang">RU</span></div><div class="ys-q">अहिंसाप्रतिष्ठायां तत्सन्निधौ वैरत्यागः — что, согласно II.35, происходит в присутствии того, кто твёрдо утвердился в ахимсе?</div><div class="ys-iast">IAST: ahiṃsāpratiṣṭhāyāṃ tatsannidhau vairatyāgaḥ — что, согласно II.35, происходит в присутствии того, кто твёрдо утвердился в ахимсе?</div><div class="ys-iast">Поисковый запрос: Que se produit-il en présence de celui qui est fermement établi dans l&#x27;ahimsa selon Yoga-Sutra II.35, ahimsāpratiṣṭhāyāṃ tatsannidhau vairatyāgaḥ ?</div><div class="ys-a"><div class="ys-label">Ответ:</div><p>К сожалению, предоставленные фрагменты не содержат текста сутры II.35 (ahiṃsāpratiṣṭhāyāṃ tatsannidhau vairatyāgaḥ) ни в переводе, ни в комментарии Вьясы (Yoga-Bhāṣya), ни в пояснениях Мишеля Ангота. Все шесть фрагментов относятся к предисловиям и общему введению (разделы «Préfaces» и «Introduction — A/B. Le Yoga-Sūtra et la tradition du yoga»), где обсуждаются вопросы личности Патанджали, филологической методологии, критики переводов citta/vṛtti и т. п., но не рассматривается вторая пада (Sādhana-pāda) и, в частности, сутра о yama и ahiṃsā.</p><p>Чтобы ответить на ваш вопрос — что, согласно сутре II.35, происходит «в присутствии» (tatsannidhau) того, кто утвердился в ненасилии (ahiṃsāpratiṣṭhāyām), а именно об «отказе от вражды» (vairatyāgaḥ) со стороны других существ, — потребуются фрагменты, посвящённые именно II.35 и комментарию Вьясы к этому сутре, которых в данной подборке нет.</p></div><div class="ys-meta">6 фрагментов (лучшие из 24 кандидатов)<br>страницы 3-5, 13-32, 71-110<br>опирается на: yoga, faces, introduction, tra, tradition, citta, tti</div></div>
# <style>
# .ys-card{border:1px solid rgba(128,128,128,.35);border-radius:12px;padding:16px 20px;margin:18px 0;height:auto;
#   max-height:none;overflow:visible;line-height:1.6;font-size:14.5px;max-width:980px}
# .ys-label{font-size:11px;letter-spacing:.09em;text-transform:uppercase;font-weight:700;opacity:.6;margin:0 0 5px}
# .ys-q{font-size:15.5px;font-weight:600;margin:0 0 4px;padding:9px 13px;border-left:4px solid #2a78d6;
#   background:rgba(42,120,214,.10);border-radius:4px;white-space:pre-wrap;overflow-wrap:anywhere}
# .ys-iast{font-size:12.5px;opacity:.7;margin:4px 0 0 17px;overflow-wrap:anywhere}
# .ys-a{margin-top:14px;overflow-wrap:anywhere}
# .ys-a p{margin:0 0 .85em}
# .ys-a h4{margin:1em 0 .4em;font-size:1em}
# .ys-a ul{margin:0 0 .85em 1.3em;padding:0}
# .ys-a li{margin:.2em 0}
# .ys-a code{background:rgba(128,128,128,.18);border-radius:4px;padding:0 4px}
# .ys-badge{display:inline-block;padding:3px 12px;border-radius:999px;font-weight:700;font-size:12.5px;color:#fff;margin-bottom:10px}
# .ys-yes{background:#0b7a4b}.ys-no{background:#b23b2e}
# .ys-lang{display:inline-block;padding:1px 8px;border-radius:999px;font-size:11px;font-weight:700;margin-left:8px;
#   border:1px solid rgba(128,128,128,.5);opacity:.8;letter-spacing:.04em}
# .ys-meta{margin-top:12px;padding-top:9px;border-top:1px dashed rgba(128,128,128,.45);font-size:12px;opacity:.75;overflow-wrap:anywhere}
# table.ys-tbl{border-collapse:collapse;font-size:13px;margin:10px 0}
# table.ys-tbl th,table.ys-tbl td{border-bottom:1px solid rgba(128,128,128,.35);padding:5px 12px;text-align:left;vertical-align:top}
# table.ys-tbl th{font-size:11px;text-transform:uppercase;letter-spacing:.06em;opacity:.7}
# </style><div class="ys-card"><div class="ys-label">Вопрос 4:<span class="ys-lang">RU</span></div><div class="ys-q">Чем отличаются друг от друга пять вритти (прамана, випарьяя, викальпа, нидра, смрити) и какие из них могут быть клишта или аклишта?</div><div class="ys-iast">Поисковый запрос: Quelles sont les différences entre les cinq vṛtti (pramāṇa, viparyaya, vikalpa, nidrā, smṛti) et lesquelles peuvent être kliṣṭa ou akliṣṭa ?</div><div class="ys-a"><div class="ys-label">Ответ:</div><p>К сожалению, предоставленные фрагменты не содержат достаточной информации для ответа на этот вопрос.</p><p>В Excerpt 1 упоминается только структура плана Йога-сутры, где указывается раздел «Les différentes vṛtti &#x27;fluctuations du mental&#x27;» (sūtra 5–11) — то есть указание на то, что в самадхи-паде (I.5–11) обсуждаются различные вритти. Однако сам перечень пяти вритти (pramāṇa, viparyaya, vikalpa, nidrā, smṛti), их определения, различия между ними, а также вопрос о том, какие из них являются kliṣṭa &#x27;омрачёнными&#x27; или akliṣṭa &#x27;неомрачёнными&#x27;, в приведённых фрагментах не раскрываются ни в тексте самой сутры, ни в Бхашье Вьясы, ни в комментарии Анго.</p><p>Чтобы ответить на этот вопрос по существу (с указанием на sūtra I.5–11, цитированием терминов IAST и разграничением, что взято из Sūtra, а что из Bhāṣya или комментария Анго), нужны дополнительные фрагменты — в частности перевод и комментарий именно к sūtra I.5, I.6, I.7, I.8, I.9, I.10, I.11, где определяются pramāṇa, viparyaya, vikalpa, nidrā и smṛti, а также обсуждается их отношение к kliṣṭa/akliṣṭa (это соотносится с sūtra I.5: kliṣṭākliṣṭāḥ).</p></div><div class="ys-meta">6 фрагментов (лучшие из 24 кандидатов)<br>страницы 33-51, 71-110<br>подвопросы: Quelles sont les différences entre les cinq vṛtti (pramāṇa, viparyaya, vikalpa, nidrā, smṛti) ? &#124; Lesquelles des cinq vṛtti (pramāṇa, viparyaya, vikalpa, nidrā, smṛti) peuvent être kliṣṭa ou akliṣṭa ?<br>опирается на: les, diff, rentes, tti, &#x27;fluctuations, mental&#x27;, tra</div></div>

# %% [markdown]
# **Cell #10**
#
# ## Сохранить рабочую папку на GitHub

# %%
# Cell #11
from reusable_code import save_to_github

save_to_github("stage2_ask_examples7_ys_RU.ipynb - Yoga-Sutra questions and answers in Russian")
